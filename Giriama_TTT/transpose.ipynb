# %%
import os
import pandas as pd

def transpose_csvs_in_folder(folder_path, output_folder=None):
    """
    Goes into a folder, picks each CSV file, transposes it, and saves it.
    
    Parameters:
        folder_path (str): Path to the folder containing CSV files.
        output_folder (str, optional): Path to save the transposed CSV files. Defaults to `folder_path`.
    """
    if output_folder is None:
        output_folder = folder_path  # Save in the same folder if no output folder is specified

    # Ensure output folder exists
    os.makedirs(output_folder, exist_ok=True)

    # Loop through each file in the folder
    for file_name in os.listdir(folder_path):
        if file_name.endswith(".csv"):
            file_path = os.path.join(folder_path, file_name)

            try:
                # Read CSV file
                df = pd.read_csv(file_path)
                print(df)

                # Transpose DataFrame
                df_transposed = df.T

                # Define new file name
                new_file_name = f"transposed_{file_name.replace('.csv', '.xlsx')}"
                new_file_path = os.path.join(output_folder, new_file_name)

                # Save transposed DataFrame
                df_transposed.to_excel(new_file_path, index=False, engine="openpyxl")

                print(f"Transposed and saved: {new_file_path}")
            except Exception as e:
                print(f"Error processing {file_name}: {e}")

# Example usage:
# transpose_csvs_in_folder("path/to/your/folder")

transpose_csvs_in_folder("/home/eric-kaz/Desktop/Semester4.2/Project /Sem2 /Giriamadatacollection/CSVs", "/home/eric-kaz/Desktop/Semester4.2/Project /Sem2 /Giriamadatacollection/Transposed_excel")
# Out:
#             Timestamp  Score  \
# 0  1/12/2025 22:05:56    NaN
# 1           Timestamp  Score
#
#   My name is Dipa tokaterica the farm Chief here at the farm Chief College  \
# 0  Dzina rangu ni Dipa Tokaterica chifu msimamizi...
# 1  My name is Dipa tokaterica the farm Chief here...
#
#   I want to share with you the good varieties of seeds which type of seed you to use to get good harvests  \
# 0  ninamala kuwa onyesa aina mbali mbali za mbeyu...
# 1  I want to share with you the good varieties of...
#
#    That's what we are looking for this time around  \
# 0                    gago ndo hunalolera msimu huu
# 1  That's what we are looking for this time around
#
#   We don't want to just engage into farming yet getting losses yet getting nothing from our sweat  \
# 0  kahunda henda mambo ga ukirima ambago ganda hu...
# 1  We don't want to just engage into farming yet ...
#
#   I want you to know which good variety of seeds you a farmer should use  \
# 0  namala mumanye mbeyu mbinzo akurima wanafaa ku...
# 1  I want you to know which good variety of seeds...
#
#   Show you who is planning to get into farming to get a profit  \
# 0          ambayo indawawezesha akurima wapate faida
# 1  Show you who is planning to get into farming t...
#
#   So this time around we are at our maize demonstration Gardens  \
# 0  wakati uu hukwenye shamba ra mafundisho wa mat...
# 1  So this time around we are at our maize demons...
#
#   I want to show you one of the best maize variety that you should use  ...  \
# 0        namala niwaonyese mbeyu mbidzo za kuhumira                     ...
# 1  I want to show you one of the best maize varie...                    ...
#
#   This amount will take your maize through to harvesting.  \
# 0                           ii indatosha mpaka uvune
# 1  This amount will take your maize through to ha...
#
#    Now, how do we go about it?  \
# 0          hundafikiradze hano
# 1  Now, how do we go about it?
#
#   When planting, apply one bottle cap (e.g., from a mineral water bottle, Rwenzori bottle, or plastic soda bottle) of fertilizer per hole.  \
# 0  ukinyala ika kifiniko kimwenga cha chupa ya ma...
# 1  When planting, apply one bottle cap (e.g., fro...
#
#    You dig the hole first.  You pour the fertilizer into the hole.  \
# 0       Tsimba wina kwanza                    ika mbolea kila wina
# 1  You dig the hole first.  You pour the fertilizer into the hole.
#
#   You can dig the hole a day or even a week before planting.  \
# 0  unaeza tsimba wina siku au ta wiki kabla ya ku...
# 1  You can dig the hole a day or even a week befo...
#
#   Allow the hole to ferment and acclimatize with the surrounding conditions before planting.  \
# 0  wezesha ro wina ku fundika ili izoere mazingir...
# 1  Allow the hole to ferment and acclimatize with...
#
#   When you are planting, get two people—one with the fertilizer and another with the seeds.  \
# 0  wakati wa kunyala pata atu airi mwenga wa mbol...
# 1  When you are planting, get two people—one with...
#
#   The person with the fertilizer is responsible for pouring fertilizer into each hole.  \
# 0    mtu wa mbolea anahusika kwa kunyala kwenye wina
# 1  The person with the fertilizer is responsible ...
#
#   The person with the seeds will check where fertilizer has been placed, cover it with a little soil, put one seed in the hole, and cover it again.
# 0  mtu wa mbeyu anahusika kulola henye mbolea na ...
# 1  The person with the seeds will check where fer...
#
# [2 rows x 112 columns]
# Transposed and saved: /home/eric-kaz/Desktop/Semester4.2/Project /Sem2 /Giriamadatacollection/Transposed_excel/transposed_Translation to Giriama form 1 (Responses) - Form Responses 1.xlsx
#             Timestamp  Score  \
# 0  1/18/2025 16:21:38    NaN
# 1           Timestamp  Score
#
#   We aim to guide and help farmers earn a decent living from farming.  \
# 0  Rengo rehu ni kuelekeza akurima wapate mapato ...
# 1  We aim to guide and help farmers earn a decent...
#
#   Faith Agro simplifies farming terminologies and science into a language that a peasant farmer can understand.  \
# 0  Faith agro inarahisisha sayansi ili akurima wa...
# 1  Faith Agro simplifies farming terminologies an...
#
#   We ensure farmers do not struggle when going to the market.  \
# 0  Hunahakikisha akurima kawang'anga'na wachenda ...
# 1  We ensure farmers do not struggle when going t...
#
#       Hello friends We grow maize or corn for the long rain maize season.  \
# 0  kamnautu enzangu   hunanyala matsere wakati wa msimu wa mvula bomu
# 1     Hello friends  We grow maize or corn for the long rain maize ...
#
#   This was done alongside us so that we can compare.  \
# 0        ino ihendwa hamwenga ili huweze kufananisha
# 1  This was done alongside us so that we can comp...
#
#   We did this so that we can compare our results with yours to give all of us hope.  \
# 0  huhenda vivi ili huweze kufananisha matokeo ge...
# 1  We did this so that we can compare our results...
#
#   We know for sure that about 70% of you got it right.  ...  \
# 0            hunamanya kala asilimia 70 mpata tototo    ...
# 1  We know for sure that about 70% of you got it ...    ...
#
#   So, passion fruit is a lucky fruit you suppose to market.  \
# 0      kwa vivyo matunda ga karakara ni madzo kuguza
# 1  So, passion fruit is a lucky fruit you suppose...
#
#    Every market has its own demand.  \
# 0  kila soko rina mahitaji ga kwake
# 1  Every market has its own demand.
#
#   Yes, for the local market, they require a fruit that is very sweet.  \
# 0       soko ra mumu mumu humala matunda garigo tamu
# 1  Yes, for the local market, they require a frui...
#
#   At the same time, they require a medium-sized fruit.  \
# 0         na kisha wanamala garigo na ubomu wa usawa
# 1  At the same time, they require a medium-sized ...
#
#   For the exports, they require high quality; don't look at the sweetness as much.  \
# 0         Soko ra konze humala ubora kawamala utamu
# 1  For the exports, they require high quality; do...
#
#    Once you have good quality passion fruit,  \
# 0         ukikala na karakara ga ubora mudzo
# 1  Once you have good quality passion fruit,
#
#   the export market does not focus on the appearance.  \
# 0             soko ra konze karimala mwonekano mudzo
# 1  the export market does not focus on the appear...
#
#   They do not mind the looks as much; they just want something that is sweet.  \
# 0      kawalola mwokekano wanamala kitu kiricho tamu
# 1  They do not mind the looks as much; they just ...
#
#   However, you will find that some customers focus on the appearance.  \
# 0              ila undapata ateja wanalola mwonekano
# 1  However, you will find that some customers foc...
#
#   If the fruit is very purple and smooth, they may dislike it because they assume it is not sweet.
# 0  tunda risirokala na rangi mbizo  kavariheza kw...
# 1  If the fruit is very purple and smooth, they m...
#
# [2 rows x 102 columns]
# Transposed and saved: /home/eric-kaz/Desktop/Semester4.2/Project /Sem2 /Giriamadatacollection/Transposed_excel/transposed_Translation to Giriama form 3 (Responses) - Form Responses 1.xlsx
#    Timestamp  Score  That is good manure.  We also have chicken manure.  \
# 0        NaN    NaN    Io ni mbeyu mbidzo       pia kuna mbolea ya kuku
# 1  Timestamp  Score  That is good manure.  We also have chicken manure.
#
#   Chicken manure is a temporary solution for plants.  It has a lot of urea.  \
# 0                mbolea ya kuku ni suluhisho ra muda       ina  Urea nyinji
# 1  Chicken manure is a temporary solution for pla...  It has a lot of urea.
#
#   Apart from the urea, there is another downside to chicken manure.  \
# 0  mbali na urea kuna tatizo ringine ra mbolea ya...
# 1  Apart from the urea, there is another downside...
#
#   Chicken manure usually comes with mites from the chicken.  \
# 0   mbolea ya kuku hudza na vidudu here huke wa kuku
# 1  Chicken manure usually comes with mites from t...
#
#   The mites will immediately find comfort in your passion fruit plants.  \
# 0                   Huke ao andavamia mumea wakwako
# 1  The mites will immediately find comfort in you...
#
#   You will realize that your plants are not growing well.  ...  \
# 0        undapata kala mimea ya kwako kaimera tototo       ...
# 1  You will realize that your plants are not grow...       ...
#
#    Every passion fruit plant produces three things:  \
# 0       kila mumea wa karakara unamboza vitu vihahu
# 1  Every passion fruit plant produces three things:
#
#    A tender shoot, a flower, and a fruit.  \
# 0                  kichipuko,lua na tunda
# 1  A tender shoot, a flower, and a fruit.
#
#    If it’s not a flower, it will produce a shoot.  \
# 0                    kala si lua undapata chipuko
# 1  If it’s not a flower, it will produce a shoot.
#
#   However, the flower and the fruit usually come at the same time.  \
# 0                   lua na tunda hudza wakati mwenga
# 1  However, the flower and the fruit usually come...
#
#   You can see here we have a shoot, and here we have a flower.  \
# 0                           Lola kuna chipuko na lua
# 1  You can see here we have a shoot, and here we ...
#
#    You will keep on discouraging the new shoots.  \
# 0                   usiriche kukale na vichupuko
# 1  You will keep on discouraging the new shoots.
#
#   Once you have left the main shoots, they are called laterals.  \
# 0  vikishakula kombola kwa shina kuu huihwa vitagaii
# 1  Once you have left the main shoots, they are c...
#
#    This is a lateral.  If you count from the base up to 1.5 meters,  \
# 0      ii ni vitahaii              ukihesabu kombola tsini mita 1.5
# 1  This is a lateral.  If you count from the base up to 1.5 meters,
#
#   You should have anywhere between 25 to 30 laterals.
# 0                   unafaa kupata vitagai 25 hadi 30
# 1  You should have anywhere between 25 to 30 late...
#
# [2 rows x 102 columns]
# Transposed and saved: /home/eric-kaz/Desktop/Semester4.2/Project /Sem2 /Giriamadatacollection/Transposed_excel/transposed_Translation to Giriama form 6 (Responses) v3 - Form Responses 1.xlsx
#             Timestamp  Score  \
# 0  1/18/2025 21:15:11    NaN
# 1           Timestamp  Score
#
#   If we count the fruits from the main branch to here, you will find there are around 15 fruits.  \
# 0  Ukihesabu namba ya matunda kwa kitagahii mpaka...
# 1  If we count the fruits from the main branch to...
#
#    You can see them.      These 15 fruits make up about a kilo.  \
# 0            mnaona   matumda kumi na tsano ni here kilo mwenga
# 1  You can see them.      These 15 fruits make up about a kilo.
#
#   If the fruits are of good size, there will be 12 or 10 fruits instead.  \
# 0           kala ni mabomu ni here matunda 12 au 10
# 1  If the fruits are of good size, there will be ...
#
#   So, you can count that each lateral branch gives about 25 fruits.  \
# 0         Kwa vivyo kila kitagai undapata matunda 25
# 1  So, you can count that each lateral branch giv...
#
#   Multiply that by 25 laterals, and you get the total amount of fruit.  \
# 0  Ukitsanganya idadi yosi kwa 25 undapata idadi ...
# 1  Multiply that by 25 laterals, and you get the ...
#
#    There are 25 fruits in number.  On the other side, they are also the same.  \
# 0                   ni matunda 25         na upande mungine ni idadi sawasawa
# 1  There are 25 fruits in number.  On the other side, they are also the same.
#
#    ... For finishing stages like this one, use Mazao Plenty.  \
# 0  ...    wakati wakati wa kumarigiza humira mazao plenty
# 1  ...  For finishing stages like this one, use Mazao ...
#
#    We also have another one called Plenty Standard.  \
# 0           pia kuna ingine inaihwa plenty standard
# 1  We also have another one called Plenty Standard.
#
#   Plenty Standard can support all growth stages of the plant.  \
# 0               plenty standard inahumika kila steji
# 1  Plenty Standard can support all growth stages ...
#
#    It has a very good formula of 25-25-20 NPK.  \
# 0                ina fomula mbidzo 25_25_20Npk
# 1  It has a very good formula of 25-25-20 NPK.
#
#   This formula can support any stage of plant growth.  \
# 0                     ii fomula inahumika kila steji
# 1  This formula can support any stage of plant gr...
#
#   It is always nice to use this fertilizer because it helps with all aspects of growth.  \
# 0  ni totot kuhumira mbole kwa sababu husaidia kw...
# 1  It is always nice to use this fertilizer becau...
#
#   At this point, if the plants are not fruiting yet, you can use it to help them grow leaves and support their care.  \
# 0  kala mimea kaiboza matunda unaweza kuwezesha i...
# 1  At this point, if the plants are not fruiting ...
#
#   A standard fertilizer helps the root system with phosphorus.  \
# 0  mbolea injine husaidia mizizi na virutubishi v...
# 1  A standard fertilizer helps the root system wi...
#
#    It helps the leaves with nitrogen.  \
# 0    inasaidia makodza na niaitrogeni
# 1  It helps the leaves with nitrogen.
#
#   It helps the ripening and setting of flowers with potassium.
# 0  Inasaidia na kuiva kwa matunda na kunawiri kwa...
# 1  It helps the ripening and setting of flowers w...
#
# [2 rows x 92 columns]
# Transposed and saved: /home/eric-kaz/Desktop/Semester4.2/Project /Sem2 /Giriamadatacollection/Transposed_excel/transposed_form 6 (Responses) - Form Responses 1.xlsx
#             Timestamp  Score  This process is simple.  \
# 0  1/17/2025 22:45:22    NaN       Ii mbinu ni rahisi
# 1           Timestamp  Score  This process is simple.
#
#   You only need three people to plant an acre—one for the fertilizer, one for scouting, and one for covering the seeds with soil.  \
# 0  Atu ahahu ndo anamalikana kunya eka mwenga,mwe...
# 1  You only need three people to plant an acre—on...
#
#    Don’t you think this spacing is too big?  No, the spacing is not too big.  \
# 0   dze mnafikiria kala zi nafasi ni bomu ?      Hata zi nafasii ta si bomu
# 1  Don’t you think this spacing is too big?  No, the spacing is not too big.
#
#             Remember, this maize variety is short.  \
# 0  mukumbuke kala i aina ya matsere ni gara matite
# 1           Remember, this maize variety is short.
#
#   When you count the number of leaves, they are fewer, and their placement is slightly shorter.  \
# 0  ukihesabu namba ya makodza ,ni machache na kui...
# 1  When you count the number of leaves, they are ...
#
#   The reason we leave enough space is to ensure the leaves can capture enough sunlight.  \
# 0  sababu ya kuricha nafasi ya kutosha ni ili mak...
# 1  The reason we leave enough space is to ensure ...
#
#   When you observe the pattern of the leaves, they grow in a single direction to maximize sunlight capture.  \
# 0  ukilola muundowa makodza hukala ganamera kwa m...
# 1  When you observe the pattern of the leaves, th...
#
#    ... Faith Agro offers a variety for every farmer's needs.  \
# 0  ...         Faith Agro inakimu mahitaji ga akurima osi
# 1  ...  Faith Agro offers a variety for every farmer's...
#
#   The number one quality of DK maize is its drought tolerance.  \
# 0  udzo mwenga wa matsere ga Dk ni kala inaweza k...
# 1  The number one quality of DK maize is its drou...
#
#    It also matures very quickly.  \
# 0          na hukula haraka sana
# 1  It also matures very quickly.
#
#   Looking at this maize, it is barely three months old.  \
# 0  lola gano matsere gana here muda wa miezi miha...
# 1  Looking at this maize, it is barely three mont...
#
#   If you are planting for the fresh market, you can start earning money within three months.  \
# 0  kala unanyala soko risha unaweza anza kupata p...
# 1  If you are planting for the fresh market, you ...
#
#   You can go to the bank, and the manager will approve your loan because you already have collateral.  \
# 0  unaeza nenda benki na meneja kukupa loni kwa s...
# 1  You can go to the bank, and the manager will a...
#
#   We call upon farmers to embrace Faith Agro inputs.  \
# 0      hunawahimiza akurima kulaki Faith agro inputs
# 1  We call upon farmers to embrace Faith Agro inp...
#
#   If you are impressed with this information and want to learn more, join our WhatsApp class.  \
# 0  kala mafundisho gaga gadzikufaa na unamala kum...
# 1  If you are impressed with this information and...
#
#    The number is +256 751 939 384.  \
# 0        namba ya +256 751 939 384
# 1  The number is +256 751 939 384.
#
#   You are welcome to share any critiques in our learning platform.
# 0  unakaribishwa ku hupa malalamishi gogosi kwa t...
# 1  You are welcome to share any critiques in our ...
#
# [2 rows x 102 columns]
# Transposed and saved: /home/eric-kaz/Desktop/Semester4.2/Project /Sem2 /Giriamadatacollection/Transposed_excel/transposed_Translation to Giriama form 2 (Responses) - Form Responses 1.xlsx
#             Timestamp  Score  \
# 0  1/18/2025 18:49:32    NaN
# 1           Timestamp  Score
#
#   But for the export market, they care more about the taste inside than the outside appearance.  \
# 0  Ila masoko ga konze humala utamu urio ndani si...
# 1  But for the export market, they care more abou...
#
#   You can advise anyone starting out that passion fruit farming is a good choice.  \
# 0  unaeza himiza atu kala ukurima wa karakara ni ...
# 1  You can advise anyone starting out that passio...
#
#    They will never regret it.  \
# 0             kawanda dziutha
# 1  They will never regret it.
#
#   You can start with passion fruits, and they are great for farming.  \
# 0  Unaeza anza na matunda ga karakara kwa sababu ...
# 1  You can start with passion fruits, and they ar...
#
#    There are three key things to consider.  \
# 0     kuna vitu vihahu muhimu vya kulolera
# 1  There are three key things to consider.
#
#    The first one is the availability of water.  \
# 0                          cha kwanza ni madzi
# 1  The first one is the availability of water.
#
#   Passion fruits require water for irrigation throughout the year.  \
# 0  mapashoni gana uhitaji wa madzi ga kunyunyizir...
# 1  Passion fruits require water for irrigation th...
#
#   Without water, your crops will face many problems.  ...  \
# 0  bila madzi ,mimera yakwako indapata thabu nyinji.  ...
# 1  Without water, your crops will face many probl...  ...
#
#    You mentioned manure.  We had manure before planting.  \
# 0          uhadza mbolea  kunaika mbolea kbla ya kunyala
# 1  You mentioned manure.  We had manure before planting.
#
#   What quantities of manure are best, and which manure is the best?  \
# 0    kiasi chani cha mbolea na mbolea hizo ni mbodzo
# 1  What quantities of manure are best, and which ...
#
#    You have good manure, even for human beings.  \
# 0               hata binadamu ana mbolea mbidzo
# 1  You have good manure, even for human beings.
#
#    That one is a very dangerous approach.  People will argue with you.  \
# 0                      io ni mbinu hatari        atu adhapingana na ue
# 1  That one is a very dangerous approach.  People will argue with you.
#
#    Good manure means it is mixed.  It’s not just from cows alone.  \
# 0   mbolea mbidzo ni mtsanganyiko    si kombola kwa ngombe hakeye
# 1  Good manure means it is mixed.  It’s not just from cows alone.
#
#    It’s not just from sheep alone.     It’s a mixture of cattle manure.
# 0     si kombola kwa gonzi  hakeye  ni mtsanganyiko wa mbolea ya ngombe
# 1  It’s not just from sheep alone.     It’s a mixture of cattle manure.
#
# [2 rows x 102 columns]
# Transposed and saved: /home/eric-kaz/Desktop/Semester4.2/Project /Sem2 /Giriamadatacollection/Transposed_excel/transposed_Translation to Giriama form 4 (Responses) - Form Responses 1.xlsx

# %%
import os
import pandas as pd

def transpose_csvs_in_folder(folder_path, output_folder=None):
    """
    Goes into a folder, picks each CSV file, transposes it (including headers), and saves it.
    
    Parameters:
        folder_path (str): Path to the folder containing CSV files.
        output_folder (str, optional): Path to save the transposed CSV files. Defaults to `folder_path`.
    """
    if output_folder is None:
        output_folder = folder_path  # Save in the same folder if no output folder is specified

    # Ensure output folder exists
    os.makedirs(output_folder, exist_ok=True)

    # Loop through each file in the folder
    for file_name in os.listdir(folder_path):
        if file_name.endswith(".csv"):
            file_path = os.path.join(folder_path, file_name)

            try:
                # Read CSV file
                df = pd.read_csv(file_path)

                # Transpose DataFrame and reset the headers correctly
                df_transposed = df.T
                df_transposed.columns = df_transposed.iloc[0]  # Set first row as column headers
                df_transposed = df_transposed[1:]  # Remove the original headers from data

                # Define new file name
                new_file_name = f"transposed_{file_name}"
                new_file_path = os.path.join(output_folder, new_file_name)

                # Save transposed DataFrame with headers
                df_transposed.to_csv(new_file_path, index=False)

                print(f"Transposed and saved: {new_file_path}")
            except Exception as e:
                print(f"Error processing {file_name}: {e}")

# Example usage:
# transpose_csvs_in_folder("path/to/your/folder")
transpose_csvs_in_folder("/home/eric-kaz/Desktop/Semester4.2/Project /Sem2 /Giriamadatacollection/CSVs", "/home/eric-kaz/Desktop/Semester4.2/Project /Sem2 /Giriamadatacollection/Transposed")
# Out:
# Transposed and saved: /home/eric-kaz/Desktop/Semester4.2/Project /Sem2 /Giriamadatacollection/Transposed/transposed_Translation to Giriama form 4.csv
# Transposed and saved: /home/eric-kaz/Desktop/Semester4.2/Project /Sem2 /Giriamadatacollection/Transposed/transposed_Translation to Giriama form 6 (Responses) - Form Responses 1.csv
# Transposed and saved: /home/eric-kaz/Desktop/Semester4.2/Project /Sem2 /Giriamadatacollection/Transposed/transposed_Translation to Giriama form 1 .csv
# Transposed and saved: /home/eric-kaz/Desktop/Semester4.2/Project /Sem2 /Giriamadatacollection/Transposed/transposed_Translation to Giriama form 3.csv
# Transposed and saved: /home/eric-kaz/Desktop/Semester4.2/Project /Sem2 /Giriamadatacollection/Transposed/transposed_Translation to Giriama form 5.csv
# Transposed and saved: /home/eric-kaz/Desktop/Semester4.2/Project /Sem2 /Giriamadatacollection/Transposed/transposed_Translation to Giriama form 6.csv
# Transposed and saved: /home/eric-kaz/Desktop/Semester4.2/Project /Sem2 /Giriamadatacollection/Transposed/transposed_Translation to Giriama form 2.csv
